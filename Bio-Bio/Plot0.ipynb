# %%
import pandas as pd
import numpy as np
import plotly.graph_objects as go
import kaleido
import matplotlib.pyplot as plt


data_folder = "/home/j/Documents/IIASA/MM-Emulator"
data_file = "magpie_input_MP00BI00nov23.csv"
figure_folder = "/".join([data_folder, "figures/"])
data_file_path = "/".join([data_folder,data_file])
data = pd.read_csv(data_file_path)

# %%
df = data[(data['Region']=='World') & (data['GHGscen']=="GHG000") & (data['Variable']=="Primary Energy|Biomass")]
df = df.drop(columns=["Region", "SSPscen", "GHGscen", "SDGscen", "1995", "2000", "2005", "2010", "2015"])
print(df)
# Out:
#                       Variable   Unit BIOscen     2020     2025     2030  \
# 1286    Primary Energy|Biomass  EJ/yr   BIO00  14.7432  14.6278  14.4968
# 19707   Primary Energy|Biomass  EJ/yr   BIO05  14.7432  14.6278  14.4968
# 38271   Primary Energy|Biomass  EJ/yr   BIO07  14.7432  14.6278  14.4968
# 56835   Primary Energy|Biomass  EJ/yr   BIO10  14.7432  14.6278  14.4968
# 75399   Primary Energy|Biomass  EJ/yr   BIO15  14.7432  14.6278  14.4968
# 93963   Primary Energy|Biomass  EJ/yr   BIO25  14.7432  14.6286  14.4968
# 112527  Primary Energy|Biomass  EJ/yr   BIO45  14.7432  14.6278  24.1074
#
#            2035      2040      2045      2050      2055      2060      2070  \
# 1286    14.3537   14.5741   16.1116   18.1319   18.9644   19.8175   21.4965
# 19707   14.3537   14.5741   16.1116   18.1319   18.9644   19.8175   21.4965
# 38271   14.3537   14.5741   16.1116   18.1319   18.9644   19.8175   21.4965
# 56835   14.3537   14.5741   16.1116   18.1319   18.9644   19.8175   58.5328
# ...

# %%
bv = df['2100'].values
bv_rev = bv * -1
print(bv_rev)
# Out:
# [ -24.2711  -24.9631 -103.7446 -295.1926 -544.8403 -641.1249 -652.3703]

# %%
ghg = data[(data['Region']=='World') & (data['BIOscen']=="BIO00") & (data['Variable']=="Price|Carbon|CO2")]
ghg = ghg.drop(columns=["Region", "SSPscen", "BIOscen", "SDGscen", "1995", "2000", "2005", "2010", "2015"])
gv = ghg['2025'].values
print(gv)
# Out:
# [  0.       0.2575   0.515    1.2876   2.5752   5.1503  10.3006  15.4509
#   25.7515  51.503   77.2545 103.006 ]

# %%
co2 = data[(data['Region']=='World') & (data['Variable']=='Emissions|CO2|AFOLU')]
co2['cumulative'] = co2['2025'] * 5 + co2['2030'] * 5 + co2['2035'] * 5 + co2['2040'] * 5 + co2['2045'] * 5 + co2['2050'] * 5 + co2['2055'] * 5 + co2['2060'] * 5 + co2['2070'] * 10 + co2['2080'] * 10 + co2['2090'] * 10 + co2['2100'] * 10
print(co2['cumulative'])
# Out:
# 480       339389.6975
# 2014      236834.8740
# 3548      178414.7895
# 5082      140244.6910
# 6616      108325.3330
#              ...
# 122537    270820.0175
# 124084    208277.4475
# 125631    141079.9855
# 127178    109660.0735
# 128725     86323.8540
# Name: cumulative, Length: 84, dtype: float64

# %%
ghgscens = co2[co2['BIOscen']=="BIO00"]['GHGscen'].values
print(ghgscens)
emis = []
#ghgscens <- dplyr::filter(co2,BIOscen=="BIO00")$GHGscen
for g in ghgscens:
   # print(co2[co2['GHGscen']==g]['cumulative'].values/1000)
    emis.append(co2[co2['GHGscen']==g]['cumulative'].values/1000)
emis_df = pd.DataFrame(emis)
#print(emis_df)
# Out:
# <StringArray>
# [ 'GHG000',  'GHG010',  'GHG020',  'GHG050',  'GHG100',  'GHG200',  'GHG400',
#   'GHG600', 'GHG1000', 'GHG2000', 'GHG3000', 'GHG4000']
# Length: 12, dtype: str

# %%
#print(emis_df.values)

# %%
fig = go.Figure(
    layout = go.Layout(
        margin=dict(
            l=0,
            r=0,
            b=0,
            t=0
        ),
        scene=dict(
            xaxis=dict(
                title = '',
                autorange="reversed",
                gridcolor='White'
            ),
            yaxis=dict(
                title=""
            ),
            zaxis=dict(
                title=""
            ),
            camera = dict(
                center = dict(
                    z = -0.2,
                    x = 0.05
                ),
                eye = dict(
                    x = 2.6,
                    y = 1.4,
                    z = 1.4                
                )
            )            
        )
    )
)

fig.add_trace(
    go.Surface(
        x = bv,
        y = gv,
        z = emis_df.values,        
        contours=dict(
            x = dict(
                show = True,
                color = "White"
            ),
            y = dict(
                show = True,
                color = "White"
            )
        )        
    )
)

fig.update_layout(
    template='plotly_white',
    plot_bgcolor = "Green",
    scene = dict(
        bgcolor = "White"
    )
)



fig.show()
#print(fig)
fig.write_image("/home/j/Documents/IIASA/MM-Emulator/figures/fig0_surface.png", width=1200, height = 1000)

# %%
fig.update_xaxes(
    mirror=True,
    ticks='outside',
    showline=True,
    linecolor='black',
    gridcolor='lightgrey'
)

fig.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('_mpl-gallery')

# Make data
X = np.arange(-5, 5, 0.25)
print(X)
Y = np.arange(-5, 5, 0.25)
X, Y = np.meshgrid(X, Y)
R = np.sqrt(X**2 + Y**2)
Z = np.sin(R)
print(X)
# Plot the surface
fig, ax = plt.subplots(subplot_kw={"projection": "3d"})
ax.plot_surface(X, Y, Z, vmin=Z.min() * 2, cmap="Blues")

ax.set(xticklabels=[],
       yticklabels=[],
       zticklabels=[])

plt.show()
# Out:
# [-5.   -4.75 -4.5  -4.25 -4.   -3.75 -3.5  -3.25 -3.   -2.75 -2.5  -2.25
#  -2.   -1.75 -1.5  -1.25 -1.   -0.75 -0.5  -0.25  0.    0.25  0.5   0.75
#   1.    1.25  1.5   1.75  2.    2.25  2.5   2.75  3.    3.25  3.5   3.75
#   4.    4.25  4.5   4.75]
# [[-5.   -4.75 -4.5  ...  4.25  4.5   4.75]
#  [-5.   -4.75 -4.5  ...  4.25  4.5   4.75]
#  [-5.   -4.75 -4.5  ...  4.25  4.5   4.75]
#  ...
#  [-5.   -4.75 -4.5  ...  4.25  4.5   4.75]
#  [-5.   -4.75 -4.5  ...  4.25  4.5   4.75]
#  [-5.   -4.75 -4.5  ...  4.25  4.5   4.75]]

# %%
print(Y)
# Out:
# [[-5.   -5.   -5.   ... -5.   -5.   -5.  ]
#  [-4.75 -4.75 -4.75 ... -4.75 -4.75 -4.75]
#  [-4.5  -4.5  -4.5  ... -4.5  -4.5  -4.5 ]
#  ...
#  [ 4.25  4.25  4.25 ...  4.25  4.25  4.25]
#  [ 4.5   4.5   4.5  ...  4.5   4.5   4.5 ]
#  [ 4.75  4.75  4.75 ...  4.75  4.75  4.75]]
